# %%
import pandas as pd

# %%
university_ranking18 = pd.read_csv('2018-QS-World-University-Rankings.csv',
                                   encoding='latin-1', header = [0,1])
university_ranking19 = pd.read_csv('2019-QS-World-University-Rankings.csv',
                                   encoding='latin-1', header = [0,1])
university_ranking20 = pd.read_csv('2020-QS-World-University-Rankings.csv',
                                   encoding='latin-1', header = [0,1])

# %%
university_ranking18.replace('-', 0,inplace=True)
university_ranking19.replace('-', 0,inplace=True)
university_ranking20.replace('-', 0,inplace=True)
university_ranking18.tail()
# Out:
#                                                   2018               2017  \
#                                     Unnamed: 0_level_1 Unnamed: 1_level_1
# 979                                                NaN                NaN
# 980  Source: QS Intelligence Unit (www.topuniversit...                NaN
# 981  You may not reconfigure the data or content in...                NaN
# 982  Under no circumstances should data be re-order...                NaN
# 983                                                NaN                NaN
#
#                                      Institution Name            Country  \
#                                    Unnamed: 2_level_1 Unnamed: 3_level_1
# 979  WHU OTTO BEISHEIM SCHOOL OF MANAGEMENT - KOBLENZ            Germany
# 980                                               NaN                NaN
# 981                                               NaN                NaN
# 982                                               NaN                NaN
# 983    Find the rankings methodology on www.iu.qs.com                NaN
#
#     Classification Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#               SIZE              FOCUS RESEARCH INTENSITY                AGE
# 979              S                 SP                 VH                3.0
# 980            NaN                NaN                NaN                NaN
# 981            NaN                NaN                NaN                NaN
# 982            NaN                NaN                NaN                NaN
# 983            NaN                NaN                NaN                NaN
#
#     Unnamed: 8_level_0 Academic Reputation  ... Unnamed: 12_level_0  \
#                 STATUS               SCORE  ...                RANK
# 979                NaN                   0  ...                   0
# 980                NaN                 NaN  ...                 NaN
# 981                NaN                 NaN  ...                 NaN
# 982                NaN                 NaN  ...                 NaN
# 983                NaN                 NaN  ...                 NaN
#
#     Faculty Student Unnamed: 14_level_0 Citations per Faculty  \
#               SCORE                RANK                 SCORE
# 979               0                   0                     0
# 980             NaN                 NaN                   NaN
# 981             NaN                 NaN                   NaN
# 982             NaN                 NaN                   NaN
# 983             NaN                 NaN                   NaN
#
#     Unnamed: 16_level_0 International Faculty Unnamed: 18_level_0  \
#                    RANK                 SCORE                RANK
# 979                   0                     0                   0
# 980                 NaN                   NaN                 NaN
# 981                 NaN                   NaN                 NaN
# 982                 NaN                   NaN                 NaN
# 983                 NaN                   NaN                 NaN
#
#     International Students Unnamed: 20_level_0       Overall Score
#                      SCORE                RANK Unnamed: 21_level_1
# 979                      0                   0                   0
# 980                    NaN                 NaN                 NaN
# 981                    NaN                 NaN                 NaN
# 982                    NaN                 NaN                 NaN
# 983                    NaN                 NaN                 NaN
#
# [5 rows x 22 columns]

# %%
def resolve_columns(df: pd.core.frame.DataFrame) -> list:
    cols = []
    rankNumber = 1
    for column in df:
        if column[0].startswith('Unnamed'):
            if column[1].startswith('RANK'):
                cols.append(column[1] + '_' + str(rankNumber))
                rankNumber +=1
            else:
                cols.append(column[1])
        elif column[1].startswith('Unnamed'):
            if column[0].startswith('RANK'):
                cols.append(column[0] + '_' + str(rankNumber))
                rankNumber +=1
            else:
                cols.append(column[0])
        else:
            cols.append(column[0] + ' ' + column[1].capitalize())
    return cols

# %%
university_ranking18.columns = resolve_columns(university_ranking18)
university_ranking19.columns = resolve_columns(university_ranking19)
university_ranking20.columns = resolve_columns(university_ranking20)

# %%
university_ranking19.head()
# Out:
#   2019 2018                              Institution Name         Country  \
# 0    1    1   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# 1    2    2                           STANFORD UNIVERSITY   United States
# 2    3    3                            HARVARD UNIVERSITY   United States
# 3    4    4  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)   United States
# 4    5    6                          UNIVERSITY OF OXFORD  United Kingdom
#
#   Classification Size FOCUS RESEARCH INTENSITY  AGE STATUS  \
# 0                   M    CO                 VH  5.0      B
# 1                   L    FC                 VH  5.0      B
# 2                   L    FC                 VH  5.0      B
# 3                   S    CO                 VH  5.0      B
# 4                   L    FC                 VH  5.0      A
#
#   Academic Reputation Score  ... RANK_2 Faculty Student Score RANK_3  \
# 0                       100  ...      4                   100     17
# 1                       100  ...      5                   100     16
# 2                       100  ...      1                  99.3     40
# 3                      98.7  ...     72                   100      4
# 4                       100  ...      3                   100      7
#
#   Citations per Faculty Score RANK_4 International Faculty Score RANK_5  \
# 0                        99.8      8                         100     41
# 1                          99     13                        99.8     56
# 2                        99.8      9                        92.1    151
# 3                         100      5                        96.8    115
# 4                          83     56                        99.6     63
#
#   International Students Score RANK_6 Overall Score
# 0                         95.5     77           100
# 1                         70.5    190          98.6
# 2                         75.7    164          98.5
# 3                         90.3    103          97.2
# 4                         98.8     43          96.8
#
# [5 rows x 22 columns]

# %%
#columns used for the determination of the rankings will be saved in a variable called det_columns
det_targ_col = ['Academic Reputation Score', 'Employer Reputation Score', 'Faculty Student Score',
               'Citations per Faculty Score', 'International Faculty Score', 'International Students Score','Overall Score']

# %%
ranking18 = university_ranking18[det_targ_col]
ranking19 = university_ranking19[det_targ_col]
ranking20 = university_ranking20[det_targ_col]

# %%
uni_18_clean = ranking18.iloc[0:501]
uni_19_clean = ranking19.iloc[0:1000]
uni_20_clean = ranking20.iloc[0:1002]

# %%
uni_18_clean.head(10)
# Out:
#   Academic Reputation Score Employer Reputation Score Faculty Student Score  \
# 0                       100                       100                   100
# 1                       100                       100                   100
# 2                       100                       100                  98.3
# 3                      99.5                      85.4                   100
# 4                       100                       100                   100
# 5                       100                       100                   100
# 6                      99.7                      99.5                  99.1
# 7                      99.4                       100                   100
# 8                      99.9                      92.9                  96.5
# 9                      99.6                      99.4                  68.2
#
#   Citations per Faculty Score International Faculty Score  \
# 0                        99.9                         100
# 1                        99.4                        99.6
# 2                        99.9                        96.5
# 3                         100                        93.4
# 4                        78.3                        97.4
# 5                        76.3                        98.6
# 6                        74.7                        96.6
# 7                        68.7                         100
# 8                        85.9                        71.9
# 9                        98.7                         100
#
#   International Students Score Overall Score
# 0                         96.1           100
# 1                         72.7          98.7
# 2                         75.2          98.4
# 3                         89.2          97.7
# 4                         97.7          95.6
# 5                         98.5          95.3
# 6                          100          94.6
# 7                          100          93.7
# 8                         79.8          93.5
# 9                         98.8          93.3

# %%
uni_18_clean.tail(10)
# Out:
#     Academic Reputation Score Employer Reputation Score Faculty Student Score  \
# 491                         0                         0                   5.6
# 492                         0                         0                    26
# 493                         0                         0                    49
# 494                         0                         0                  92.6
# 495                         0                         0                  21.1
# 496                         0                         0                  34.7
# 497                         0                         0                  27.4
# 498                         0                         0                  70.2
# 499                         0                         0                   9.5
# 500                         0                         0                  73.5
#
#     Citations per Faculty Score International Faculty Score  \
# 491                          33                        19.1
# 492                         9.5                         5.9
# 493                        20.1                        16.7
# 494                         NaN                        19.5
# 495                        10.9                         3.2
# 496                        21.8                         8.1
# 497                        10.8                         5.9
# 498                         2.2                        59.9
# 499                        40.9                        46.9
# 500                         1.7                        13.5
#
#     International Students Score Overall Score
# 491                         16.5          25.8
# 492                         42.3          25.7
# 493                          3.3          25.6
# 494                          9.4          25.3
# 495                         33.6          25.2
# 496                         11.1          25.2
# 497                          3.3          25.8
# 498                          9.3          25.6
# 499                         15.5          25.3
# 500                         19.2          25.3

# %%
uni_19_clean.head(10)
# Out:
#   Academic Reputation Score Employer Reputation Score Faculty Student Score  \
# 0                       100                       100                   100
# 1                       100                       100                   100
# 2                       100                       100                  99.3
# 3                      98.7                      81.2                   100
# 4                       100                       100                   100
# 5                       100                       100                   100
# 6                      98.2                      96.2                  82.4
# 7                      98.7                      99.9                  99.9
# 8                      99.6                      90.7                  97.4
# 9                      99.3                      99.2                  99.2
#
#   Citations per Faculty Score International Faculty Score  \
# 0                        99.8                         100
# 1                          99                        99.8
# 2                        99.8                        92.1
# 3                         100                        96.8
# 4                          83                        99.6
# 5                        77.2                        99.4
# 6                        98.7                         100
# 7                        67.8                         100
# 8                        83.6                        74.2
# 9                        66.2                        98.7
#
#   International Students Score Overall Score
# 0                         95.5           100
# 1                         70.5          98.6
# 2                         75.7          98.5
# 3                         90.3          97.2
# 4                         98.8          96.8
# 5                         97.9          95.6
# 6                         98.6          95.3
# 7                          100          93.3
# 8                         82.5          93.2
# 9                          100          92.9

# %%
uni_19_clean.tail(10)
# Out:
#     Academic Reputation Score Employer Reputation Score Faculty Student Score  \
# 990                         0                         0                     0
# 991                         0                         0                     0
# 992                         0                         0                  29.6
# 993                         0                         0                     0
# 994                         0                      17.9                  25.3
# 995                         0                         0                  40.2
# 996                         0                         0                     0
# 997                         0                         0                     0
# 998                         0                      17.9                     0
# 999                         0                         0                     0
#
#     Citations per Faculty Score International Faculty Score  \
# 990                           0                        37.1
# 991                        33.5                           0
# 992                           0                           0
# 993                        26.4                           0
# 994                           0                           0
# 995                           0                           0
# 996                           0                        28.1
# 997                           0                           0
# 998                           0                         NaN
# 999                        19.1                        27.8
#
#     International Students Score Overall Score
# 990                         53.5    7.2 - 14.2
# 991                            0    7.2 - 14.2
# 992                            0    7.2 - 14.2
# 993                            0    7.2 - 14.2
# 994                            0    7.2 - 14.2
# 995                         18.1    7.2 - 14.2
# 996                            0    7.2 - 14.2
# 997                            0    7.2 - 14.2
# 998                          NaN    7.2 - 14.2
# 999                            0    7.2 - 14.2

# %%
uni_20_clean.head(10)
# Out:
#   Academic Reputation Score Employer Reputation Score Faculty Student Score  \
# 0                       100                       100                   100
# 1                       100                       100                   100
# 2                       100                       100                  98.7
# 3                       100                       100                   100
# 4                      97.8                      81.2                   100
# 5                      98.4                      96.7                    85
# 6                       100                       100                   100
# 7                      99.3                      98.7                  98.1
# 8                      98.6                      99.9                  99.8
# 9                      99.5                      93.7                  96.5
#
#   Citations per Faculty Score International Faculty Score  \
# 0                        99.8                         100
# 1                        98.6                        99.8
# 2                        99.6                        86.3
# 3                        84.7                        99.7
# 4                         100                        99.4
# 5                        98.4                         100
# 6                        74.2                         100
# 7                        76.7                        99.1
# 8                        72.1                         100
# 9                        78.5                        70.2
#
#   International Students Score Overall Score
# 0                         94.1           100
# 1                         67.7          98.4
# 2                         62.2          97.4
# 3                         98.5          97.2
# 4                         87.3          96.9
# 5                           98          95.9
# 6                         97.6            95
# 7                          100          94.8
# 8                          100          94.1
# 9                           81            92

# %%
uni_20_clean.tail(10)
# Out:
#      Academic Reputation Score Employer Reputation Score  \
# 992                          0                         0
# 993                          0                         0
# 994                          0                         0
# 995                          0                         0
# 996                          0                         0
# 997                          0                         0
# 998                          0                         0
# 999                          0                         0
# 1000                         0                         0
# 1001                         0                         0
#
#      Faculty Student Score Citations per Faculty Score  \
# 992                      0                           0
# 993                      0                          31
# 994                      0                           0
# 995                   37.3                           0
# 996                      0                           0
# 997                   28.8                           0
# 998                   26.3                           0
# 999                      0                        18.9
# 1000                     0                           0
# 1001                     0                        23.4
#
#      International Faculty Score International Students Score Overall Score
# 992                            0                            0      9 - 14.1
# 993                            0                            0      9 - 14.1
# 994                            0                            0      9 - 14.1
# 995                            0                         16.3      9 - 14.1
# 996                         17.4                            0      9 - 14.1
# 997                            0                            0      9 - 14.1
# 998                            0                            0      9 - 14.1
# 999                            0                            0      9 - 14.1
# 1000                         100                            0      9 - 14.1
# 1001                        21.9                            0      9 - 14.1
