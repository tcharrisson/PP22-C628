# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/helen-oy/data-science-internship-hamoye/main/2018-QS-World-University-Rankings.csv', encoding='latin-1')

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/helen-oy/data-science-internship-hamoye/main/2019-QS-World-University-Rankings.csv', encoding='latin-1')
df3=pd.read_csv('https://raw.githubusercontent.com/helen-oy/data-science-internship-hamoye/main/2020-QS-World-University-Rankings.csv', encoding='latin-1')

# %%
df1.shape
# Out:
# (985, 22)

# %%
df2.shape
# Out:
# (1026, 22)

# %%
df3.shape
# Out:
# (1025, 22)

# %%
df1
df2
df3
# Out:
#      Rank in 2020 Rank in 2019  \
# 0             NaN          NaN
# 1               1            1
# 2               2            2
# 3               3            3
# 4               4            5
# ...           ...          ...
# 1020          NaN          NaN
# 1021          NaN          NaN
# 1022          NaN          NaN
# 1023          NaN          NaN
# 1024          NaN          NaN
#
#                                       Institution Name         Country  \
# 0                                                  NaN             NaN
# 1          Massachusetts Institute of Technology (MIT)   United States
# 2                                  Stanford University   United States
# 3                                   Harvard University   United States
# 4                                 University of Oxford  United Kingdom
# ...                                                ...             ...
# 1020              Université Sorbonne Nouvelle Paris 3          France
# ...

# %%
df1.head()
# Out:
#   2018 2017                              Institution Name        Country  \
# 0  NaN  NaN                                           NaN            NaN
# 1    1    1  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# 2    2    2                           STANFORD UNIVERSITY  United States
# 3    3    3                            HARVARD UNIVERSITY  United States
# 4    4    5  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)  United States
#
#   Classification Unnamed: 5          Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0           SIZE      FOCUS  RESEARCH INTENSITY        AGE     STATUS
# 1              M         CO                  VH          5          B
# 2              L         FC                  VH          5          B
# 3              L         FC                  VH          5          B
# 4              S         CO                  VH          5          B
#
#   Academic Reputation  ... Unnamed: 12 Faculty Student Unnamed: 14  \
# ...

# %% [markdown]
# # cleaning 2018 data

# %%
df1.isnull().sum()
# Out:
# 2018                      23
# 2017                      71
# Institution Name           4
# Country                    5
# Classification             4
# Unnamed: 5                15
# Unnamed: 6                16
# Unnamed: 7                25
# Unnamed: 8                22
# Academic Reputation        4
# Unnamed: 10                4
# Employer Reputation        4
# Unnamed: 12                4
# Faculty Student            4
# Unnamed: 14                4
# Citations per Faculty      5
# Unnamed: 16                5
# International Faculty     10
# Unnamed: 18               10
# International Students     5
# Unnamed: 20                5
# Overall Score              5
# dtype: int64

# %%
col=df1.columns

# %%
df1.columns
# Out:
# Index(['2018', '2017', 'Institution Name', 'Country', 'Classification',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Academic Reputation', 'Unnamed: 10', 'Employer Reputation',
#        'Unnamed: 12', 'Faculty Student', 'Unnamed: 14',
#        'Citations per Faculty', 'Unnamed: 16', 'International Faculty',
#        'Unnamed: 18', 'International Students', 'Unnamed: 20',
#        'Overall Score'],
#       dtype='object')

# %%
print('Number of columns:', len(col))
# Out:
# Number of columns: 22

# %%
df1 = df1.rename(columns = {'Classification':'Classification_size', 'Unnamed: 5': 'Focus', 'Unnamed: 6':'Research Intensity', 'Unnamed: 7':'Age', 'Unnamed: 8':'Status', 'Academic Reputation':'Academic_Reputation_RANK', 'Unnamed: 10':'Academic_Reputation_SCORE', 'Employer Reputation':'Employer_Reputation_RANK', 'Unnamed: 12':'Employer_Reputation_SCORE', 'Faculty Student':'Faculty_Student_RANK', 'Unnamed: 14':'Faculty_Student_SCORE','Citations per Faculty':'Citations_per_Faculty_RANK', 'Unnamed: 16':'Citations_per_Faculty_SCORE', 'International Faculty':'International_Faculty_RANK','Unnamed: 18':'International_Faculty_SCORE', 'International Students':'International_Students_RANK', 'Unnamed: 20':'International_Students_SCORE'})

# %%
df1
# Out:
#                                                   2018 2017  \
# 0                                                  NaN  NaN
# 1                                                    1    1
# 2                                                    2    2
# 3                                                    3    3
# 4                                                    4    5
# ..                                                 ...  ...
# 980                                                NaN  NaN
# 981  Source: QS Intelligence Unit (www.topuniversit...  NaN
# 982  You may not reconfigure the data or content in...  NaN
# 983  Under no circumstances should data be re-order...  NaN
# 984                                                NaN  NaN
#
#                                      Institution Name        Country  \
# 0                                                 NaN            NaN
# 1        MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# ...

# %%
df1=df1.drop(0)

# %%
df1.reset_index(inplace=True, drop=True)

# %%
df1
# Out:
#                                                   2018 2017  \
# 0                                                    1    1
# 1                                                    2    2
# 2                                                    3    3
# 3                                                    4    5
# 4                                                    5    4
# ..                                                 ...  ...
# 979                                                NaN  NaN
# 980  Source: QS Intelligence Unit (www.topuniversit...  NaN
# 981  You may not reconfigure the data or content in...  NaN
# 982  Under no circumstances should data be re-order...  NaN
# 983                                                NaN  NaN
#
#                                      Institution Name         Country  \
# 0        MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)    United States
# 1                                 STANFORD UNIVERSITY   United States
# ...

# %% [markdown]
# sorting missing values

# %%
df1.isnull().sum()
# Out:
# 2018                            22
# 2017                            70
# Institution Name                 3
# Country                          4
# Classification_size              4
# Focus                           15
# Research Intensity              16
# Age                             25
# Status                          22
# Academic_Reputation_RANK         4
# Academic_Reputation_SCORE        4
# Employer_Reputation_RANK         4
# Employer_Reputation_SCORE        4
# Faculty_Student_RANK             4
# Faculty_Student_SCORE            4
# Citations_per_Faculty_RANK       5
# Citations_per_Faculty_SCORE      5
# International_Faculty_RANK      10
# International_Faculty_SCORE     10
# International_Students_RANK      5
# International_Students_SCORE     5
# Overall Score                    4
# dtype: int64

# %%
df1.info
# Out:
# <bound method DataFrame.info of                                                   2018 2017  \
# 0                                                    1    1
# 1                                                    2    2
# 2                                                    3    3
# 3                                                    4    5
# 4                                                    5    4
# ..                                                 ...  ...
# 979                                                NaN  NaN
# 980  Source: QS Intelligence Unit (www.topuniversit...  NaN
# 981  You may not reconfigure the data or content in...  NaN
# 982  Under no circumstances should data be re-order...  NaN
# 983                                                NaN  NaN
#
#                                      Institution Name         Country  \
# 0        MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)    United States
# 1                                 STANFORD UNIVERSITY   United States
# ...

# %%
df1.replace('-', np.nan, inplace=True)
print(df1)
# Out:
#                                                   2018 2017  \
# 0                                                    1    1
# 1                                                    2    2
# 2                                                    3    3
# 3                                                    4    5
# 4                                                    5    4
# ..                                                 ...  ...
# 979                                                NaN  NaN
# 980  Source: QS Intelligence Unit (www.topuniversit...  NaN
# 981  You may not reconfigure the data or content in...  NaN
# 982  Under no circumstances should data be re-order...  NaN
# 983                                                NaN  NaN
#
#                                      Institution Name         Country  \
# 0        MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)    United States
# 1                                 STANFORD UNIVERSITY   United States
# ...

# %%
isinstance(df1.iloc[22,0], int)
# Out:
# False

# %%
df1.dtypes
# Out:
# 2018                            object
# 2017                            object
# Institution Name                object
# Country                         object
# Classification_size             object
# Focus                           object
# Research Intensity              object
# Age                             object
# Status                          object
# Academic_Reputation_RANK        object
# Academic_Reputation_SCORE       object
# Employer_Reputation_RANK        object
# Employer_Reputation_SCORE       object
# Faculty_Student_RANK            object
# Faculty_Student_SCORE           object
# Citations_per_Faculty_RANK      object
# Citations_per_Faculty_SCORE     object
# International_Faculty_RANK      object
# International_Faculty_SCORE     object
# International_Students_RANK     object
# International_Students_SCORE    object
# Overall Score                   object
# dtype: object

# %%
df1_ranking_only_2018= df1[df1['2018'].isnull()]
df1_ranking_only_2018
# Out:
#     2018    2017                                   Institution Name  \
# 959  NaN     NaN                         BAYLOR COLLEGE OF MEDICINE
# 960  NaN     NaN                       BI NORWEGIAN BUSINESS SCHOOL
# 961  NaN    386=                              CHUNG-ANG UNIVERSITY
# 962  NaN     NaN                         COPENHAGEN BUSINESS SCHOOL
# 963  NaN     NaN                               CRANFIELD UNIVERSITY
# 964  NaN     NaN                                        ESCP EUROPE
# 965  NaN     NaN                       ESSEC BUSINESS SCHOOL, PARIS
# 966  NaN     NaN                           EUROPEAN BUSINESS SCHOOL
# 967  NaN     NaN                                          HEC PARIS
# 968  NaN     NaN                                    INSEAD (FRANCE)
# 969  NaN     NaN                        JAWAHARLAL NEHRU UNIVERSITY
# 970  NaN     NaN                               KAROLINSKA INSTITUTE
# 971  NaN     NaN  KING ABDULLAH UNIVERSITY OF SCIENCE & TECHNOLO...
# ...

# %% [markdown]
# visualizing missing data

# %%
import missingno as msno

# %%
# %matplotlib inline

# %%
msno.matrix(df1.sample(250))
# Out:
# <AxesSubplot:>

# %%
msno.bar(df1.sample(500))
# Out:
# <AxesSubplot:>

# %% [markdown]
# to get the correlation between missing valuesusing heat map
# The missingno correlation heatmap measures nullity correlation: how strongly the presence or absence of one variable affects the presence of another

# %%
msno.heatmap(df1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Nullity correlation ranges from -1 (if one variable appears the other definitely does not) to 0 (variables appearing or not appearing have no effect on one another) to 1 (if one variable appears the other definitely also does).
# 1. it can be inferred from the heat map that classification features such as age, status, classification size, research intensity are highly uncorrelated with 0.1 values, that is features appearing or not appearing have no effect on one another
# 2. Citations_per_Faculty_RANK, international_faculty_rank, the international students rank is directly correlated to the overall score giving a correlation of 1

# %%
df1 = df1.iloc[:, [i for i, n in enumerate(np.var(df1.isnull(), axis='rows')) if n > 0]]
corr_mat = df1.isnull().corr()
print(corr_mat)
# Out:
#                                   2018      2017  Institution Name   Country  \
# 2018                          1.000000  0.519706         -0.008363  0.098371
# 2017                          0.519706  1.000000          0.199825  0.230856
# Institution Name             -0.008363  0.199825          1.000000  0.865584
# Country                       0.098371  0.230856          0.865584  1.000000
# Classification_size           0.098371  0.230856          0.865584  1.000000
# Focus                         0.037288  0.320511          0.444470  0.513491
# Research Intensity            0.034908  0.308270          0.430134  0.496929
# Age                           0.019267  0.432679          0.342504  0.395691
# Status                        0.070119  0.519706          0.365681  0.422467
# Academic_Reputation_RANK      0.125155  0.204887          0.045767  0.052874
# Academic_Reputation_SCORE     0.125155  0.204887          0.045767  0.052874
# ...

# %%
#drop features not used for ranking  :Classification_size', 'Focus','Research Intensity' 'Age', 'Size']
to_drop =['Classification_size', 'Focus','Research Intensity', 'Age', 'Status']
df1_rankingfactors = df1.drop(to_drop, axis=1)
print (df1_rankingfactors)
# Out:
#                                                   2018 2017  \
# 0                                                    1    1
# 1                                                    2    2
# 2                                                    3    3
# 3                                                    4    5
# 4                                                    5    4
# ..                                                 ...  ...
# 979                                                NaN  NaN
# 980  Source: QS Intelligence Unit (www.topuniversit...  NaN
# 981  You may not reconfigure the data or content in...  NaN
# 982  Under no circumstances should data be re-order...  NaN
# 983                                                NaN  NaN
#
#                                      Institution Name         Country  \
# 0        MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)    United States
# 1                                 STANFORD UNIVERSITY   United States
# ...

# %% [markdown]
# # cleaning 2019 data

# %%
df2.isnull().sum()
# Out:
# 2019                      23
# 2018                      87
# Institution Name           4
# Country                    5
# Classification             4
# Unnamed: 5                 4
# Unnamed: 6                 4
# Unnamed: 7                 4
# Unnamed: 8                 4
# Academic Reputation        4
# Unnamed: 10                4
# Employer Reputation        6
# Unnamed: 12                4
# Faculty Student            4
# Unnamed: 14                4
# Citations per Faculty      4
# Unnamed: 16                4
# International Faculty     61
# Unnamed: 18               11
# International Students    17
# Unnamed: 20                5
# Overall Score              5
# dtype: int64

# %%
col=df2.columns

# %%
df2.columns
# Out:
# Index(['2019', '2018', 'Institution Name', 'Country', 'Classification',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Academic Reputation', 'Unnamed: 10', 'Employer Reputation',
#        'Unnamed: 12', 'Faculty Student', 'Unnamed: 14',
#        'Citations per Faculty', 'Unnamed: 16', 'International Faculty',
#        'Unnamed: 18', 'International Students', 'Unnamed: 20',
#        'Overall Score'],
#       dtype='object')

# %%
print('Number of columns:', len(col))
# Out:
# Number of columns: 22

# %%
df2 = df2.rename(columns = {'Classification':'Classification_size', 'Unnamed: 5': 'Focus', 'Unnamed: 6':'Research Intensity', 'Unnamed: 7':'Age', 'Unnamed: 8':'Status', 'Academic Reputation':'Academic_Reputation_RANK', 'Unnamed: 10':'Academic_Reputation_SCORE', 'Employer Reputation':'Employer_Reputation_RANK', 'Unnamed: 12':'Employer_Reputation_SCORE', 'Faculty Student':'Faculty_Student_RANK', 'Unnamed: 14':'Faculty_Student_SCORE','Citations per Faculty':'Citations_per_Faculty_RANK', 'Unnamed: 16':'Citations_per_Faculty_SCORE', 'International Faculty':'International_Faculty_RANK','Unnamed: 18':'International_Faculty_SCORE', 'International Students':'International_Students_RANK', 'Unnamed: 20':'International_Students_SCORE'})

# %%
df2
# Out:
#                                                    2019 2018  \
# 0                                                   NaN  NaN
# 1                                                     1    1
# 2                                                     2    2
# 3                                                     3    3
# 4                                                     4    4
# ...                                                 ...  ...
# 1021                                                NaN  NaN
# 1022  Source: QS Intelligence Unit (www.topuniversit...  NaN
# 1023  You may not reconfigure the data or content in...  NaN
# 1024  Under no circumstances should data be re-order...  NaN
# 1025                                                NaN  NaN
#
#                                       Institution Name        Country  \
# 0                                                  NaN            NaN
# 1          MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)  United States
# ...

# %%
df2=df2.drop(0)

df2.reset_index(inplace=True, drop=True)
df2
# Out:
#                                                    2019 2018  \
# 0                                                     1    1
# 1                                                     2    2
# 2                                                     3    3
# 3                                                     4    4
# 4                                                     5    6
# ...                                                 ...  ...
# 1020                                                NaN  NaN
# 1021  Source: QS Intelligence Unit (www.topuniversit...  NaN
# 1022  You may not reconfigure the data or content in...  NaN
# 1023  Under no circumstances should data be re-order...  NaN
# 1024                                                NaN  NaN
#
#                                       Institution Name         Country  \
# 0          MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# 1                                  STANFORD UNIVERSITY   United States
# ...

# %% [markdown]
# sorting missing values

# %%
df2.isnull().sum()
# Out:
# 2019                            22
# 2018                            86
# Institution Name                 3
# Country                          4
# Classification_size              4
# Focus                            4
# Research Intensity               4
# Age                              4
# Status                           4
# Academic_Reputation_RANK         4
# Academic_Reputation_SCORE        4
# Employer_Reputation_RANK         6
# Employer_Reputation_SCORE        4
# Faculty_Student_RANK             4
# Faculty_Student_SCORE            4
# Citations_per_Faculty_RANK       4
# Citations_per_Faculty_SCORE      4
# International_Faculty_RANK      61
# International_Faculty_SCORE     11
# International_Students_RANK     17
# International_Students_SCORE     5
# Overall Score                    4
# dtype: int64

# %%
df2.info
# Out:
# <bound method DataFrame.info of                                                    2019 2018  \
# 0                                                     1    1
# 1                                                     2    2
# 2                                                     3    3
# 3                                                     4    4
# 4                                                     5    6
# ...                                                 ...  ...
# 1020                                                NaN  NaN
# 1021  Source: QS Intelligence Unit (www.topuniversit...  NaN
# 1022  You may not reconfigure the data or content in...  NaN
# 1023  Under no circumstances should data be re-order...  NaN
# 1024                                                NaN  NaN
#
#                                       Institution Name         Country  \
# 0          MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# ...

# %%
df2.replace('-', np.nan, inplace=True)
print(df2)
# Out:
#                                                    2019 2018  \
# 0                                                     1    1
# 1                                                     2    2
# 2                                                     3    3
# 3                                                     4    4
# 4                                                     5    6
# ...                                                 ...  ...
# 1020                                                NaN  NaN
# 1021  Source: QS Intelligence Unit (www.topuniversit...  NaN
# 1022  You may not reconfigure the data or content in...  NaN
# 1023  Under no circumstances should data be re-order...  NaN
# 1024                                                NaN  NaN
#
#                                       Institution Name         Country  \
# 0          MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# 1                                  STANFORD UNIVERSITY   United States
# ...

# %%
isinstance(df2.iloc[22,0], int)
# Out:
# False

# %%
df2.dtypes
# Out:
# 2019                            object
# 2018                            object
# Institution Name                object
# Country                         object
# Classification_size             object
# Focus                           object
# Research Intensity              object
# Age                             object
# Status                          object
# Academic_Reputation_RANK        object
# Academic_Reputation_SCORE       object
# Employer_Reputation_RANK        object
# Employer_Reputation_SCORE       object
# Faculty_Student_RANK            object
# Faculty_Student_SCORE           object
# Citations_per_Faculty_RANK      object
# Citations_per_Faculty_SCORE     object
# International_Faculty_RANK      object
# International_Faculty_SCORE     object
# International_Students_RANK     object
# International_Students_SCORE    object
# Overall Score                   object
# dtype: object

# %%
df2_ranking_only_2019= df2[df2['2019'].isnull()]
df2_ranking_only_2019
# Out:
#      2019 2018                                   Institution Name  \
# 1000  NaN  NaN                         BAYLOR COLLEGE OF MEDICINE
# 1001  NaN  NaN                       BI NORWEGIAN BUSINESS SCHOOL
# 1002  NaN  NaN                        CENTRAL EUROPEAN UNIVERSITY
# 1003  NaN  NaN                         COPENHAGEN BUSINESS SCHOOL
# 1004  NaN  NaN                               CRANFIELD UNIVERSITY
# 1005  NaN  NaN                                        ESCP EUROPE
# 1006  NaN  NaN                       ESSEC BUSINESS SCHOOL, PARIS
# 1007  NaN  NaN     GRENOBLE INP, GRENOBLE INSTITUTE OF TECHNOLOGY
# 1008  NaN  NaN                                          HEC PARIS
# 1009  NaN  NaN                                    INSEAD (FRANCE)
# 1010  NaN  NaN                        JAWAHARLAL NEHRU UNIVERSITY
# 1011  NaN  NaN                               KAROLINSKA INSTITUTE
# 1012  NaN  NaN  KING ABDULLAH UNIVERSITY OF SCIENCE & TECHNOLO...
# ...

# %% [markdown]
# visualizing missing data

# %%
import missingno as msno

# %matplotlib inline

# %%
msno.matrix(df2.sample(250))
# Out:
# <AxesSubplot:>

# %%
msno.bar(df2.sample(500))
# Out:
# <AxesSubplot:>

# %% [markdown]
# to get the correlation between missing valuesusing heat map
# The missingno correlation heatmap measures nullity correlation: how strongly the presence or absence of one variable affects the presence of another

# %%
msno.heatmap(df2)
# Out:
# <AxesSubplot:>

# %%
df2 = df2.iloc[:, [i for i, n in enumerate(np.var(df2.isnull(), axis='rows')) if n > 0]]
corr_mat = df2.isnull().corr()
print(corr_mat)
# Out:
#                                   2019      2018  Institution Name   Country  \
# 2019                          1.000000  0.489378         -0.008024  0.098704
# 2018                          0.489378  1.000000          0.179027  0.206824
# Institution Name             -0.008024  0.179027          1.000000  0.865602
# Country                       0.098704  0.206824          0.865602  1.000000
# Classification_size           0.098704  0.206824          0.865602  1.000000
# Focus                         0.098704  0.206824          0.865602  1.000000
# Research Intensity            0.098704  0.206824          0.865602  1.000000
# Age                           0.098704  0.206824          0.865602  1.000000
# Status                        0.098704  0.206824          0.865602  1.000000
# Academic_Reputation_RANK      0.039020  0.230332          0.064246  0.074221
# Academic_Reputation_SCORE     0.039020  0.230332          0.064246  0.074221
# ...

# %%
#drop features not used for ranking  :Classification_size', 'Focus','Research Intensity' 'Age', 'Size']
to_drop =['Classification_size', 'Focus','Research Intensity', 'Age', 'Status']
df2_rankingfactors = df2.drop(to_drop, axis=1)
print (df2_rankingfactors)
# Out:
#                                                    2019 2018  \
# 0                                                     1    1
# 1                                                     2    2
# 2                                                     3    3
# 3                                                     4    4
# 4                                                     5    6
# ...                                                 ...  ...
# 1020                                                NaN  NaN
# 1021  Source: QS Intelligence Unit (www.topuniversit...  NaN
# 1022  You may not reconfigure the data or content in...  NaN
# 1023  Under no circumstances should data be re-order...  NaN
# 1024                                                NaN  NaN
#
#                                       Institution Name         Country  \
# 0          MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# 1                                  STANFORD UNIVERSITY   United States
# ...

# %% [markdown]
# # cleaning 2020 data

# %%
df3.isnull().sum()
# Out:
# Rank in 2020              23
# Rank in 2019              73
# Institution Name           1
# Country                    1
# Classification             0
# Unnamed: 5                23
# Unnamed: 6                24
# Unnamed: 7                23
# Unnamed: 8                42
# Academic Reputation        0
# Unnamed: 10                0
# Employer Reputation        0
# Unnamed: 12                0
# Faculty Student            0
# Unnamed: 14                0
# Citations per Faculty      0
# Unnamed: 16                0
# International Faculty     46
# Unnamed: 18                5
# International Students     6
# Unnamed: 20                1
# Overall Score              1
# dtype: int64

# %%
col=df3.columns

# %%
df3.columns
# Out:
# Index(['Rank in 2020', 'Rank in 2019', 'Institution Name', 'Country',
#        'Classification', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Academic Reputation', 'Unnamed: 10',
#        'Employer Reputation', 'Unnamed: 12', 'Faculty Student', 'Unnamed: 14',
#        'Citations per Faculty', 'Unnamed: 16', 'International Faculty',
#        'Unnamed: 18', 'International Students', 'Unnamed: 20',
#        'Overall Score'],
#       dtype='object')

# %%
print('Number of columns:', len(col))
# Out:
# Number of columns: 22

# %%
df3 = df3.rename(columns = {'Classification':'Classification_size', 'Unnamed: 5': 'Focus', 'Unnamed: 6':'Research Intensity', 'Unnamed: 7':'Age', 'Unnamed: 8':'Status', 'Academic Reputation':'Academic_Reputation_RANK', 'Unnamed: 10':'Academic_Reputation_SCORE', 'Employer Reputation':'Employer_Reputation_RANK', 'Unnamed: 12':'Employer_Reputation_SCORE', 'Faculty Student':'Faculty_Student_RANK', 'Unnamed: 14':'Faculty_Student_SCORE','Citations per Faculty':'Citations_per_Faculty_RANK', 'Unnamed: 16':'Citations_per_Faculty_SCORE', 'International Faculty':'International_Faculty_RANK','Unnamed: 18':'International_Faculty_SCORE', 'International Students':'International_Students_RANK', 'Unnamed: 20':'International_Students_SCORE'})

# %%
df3
# Out:
#      Rank in 2020 Rank in 2019  \
# 0             NaN          NaN
# 1               1            1
# 2               2            2
# 3               3            3
# 4               4            5
# ...           ...          ...
# 1020          NaN          NaN
# 1021          NaN          NaN
# 1022          NaN          NaN
# 1023          NaN          NaN
# 1024          NaN          NaN
#
#                                       Institution Name         Country  \
# 0                                                  NaN             NaN
# 1          Massachusetts Institute of Technology (MIT)   United States
# 2                                  Stanford University   United States
# 3                                   Harvard University   United States
# 4                                 University of Oxford  United Kingdom
# ...                                                ...             ...
# 1020              Université Sorbonne Nouvelle Paris 3          France
# ...

# %%
df3=df3.drop(0)

df3.reset_index(inplace=True, drop=True)
df3
# Out:
#      Rank in 2020 Rank in 2019  \
# 0               1            1
# 1               2            2
# 2               3            3
# 3               4            5
# 4               5            4
# ...           ...          ...
# 1019          NaN          NaN
# 1020          NaN          NaN
# 1021          NaN          NaN
# 1022          NaN          NaN
# 1023          NaN          NaN
#
#                                       Institution Name         Country  \
# 0          Massachusetts Institute of Technology (MIT)   United States
# 1                                  Stanford University   United States
# 2                                   Harvard University   United States
# 3                                 University of Oxford  United Kingdom
# 4         California Institute of Technology (Caltech)   United States
# ...                                                ...             ...
# 1019              Université Sorbonne Nouvelle Paris 3          France
# ...

# %% [markdown]
# sorting missing values

# %%
df3.isnull().sum()
# Out:
# Rank in 2020                    22
# Rank in 2019                    72
# Institution Name                 0
# Country                          0
# Classification_size              0
# Focus                           23
# Research Intensity              24
# Age                             23
# Status                          42
# Academic_Reputation_RANK         0
# Academic_Reputation_SCORE        0
# Employer_Reputation_RANK         0
# Employer_Reputation_SCORE        0
# Faculty_Student_RANK             0
# Faculty_Student_SCORE            0
# Citations_per_Faculty_RANK       0
# Citations_per_Faculty_SCORE      0
# International_Faculty_RANK      46
# International_Faculty_SCORE      5
# International_Students_RANK      6
# International_Students_SCORE     1
# Overall Score                    0
# dtype: int64

# %%
df3.info
# Out:
# <bound method DataFrame.info of      Rank in 2020 Rank in 2019  \
# 0               1            1
# 1               2            2
# 2               3            3
# 3               4            5
# 4               5            4
# ...           ...          ...
# 1019          NaN          NaN
# 1020          NaN          NaN
# 1021          NaN          NaN
# 1022          NaN          NaN
# 1023          NaN          NaN
#
#                                       Institution Name         Country  \
# 0          Massachusetts Institute of Technology (MIT)   United States
# 1                                  Stanford University   United States
# 2                                   Harvard University   United States
# 3                                 University of Oxford  United Kingdom
# 4         California Institute of Technology (Caltech)   United States
# ...                                                ...             ...
# ...

# %%
df3.replace('-', np.nan, inplace=True)
print(df3)
# Out:
#      Rank in 2020 Rank in 2019  \
# 0               1            1
# 1               2            2
# 2               3            3
# 3               4            5
# 4               5            4
# ...           ...          ...
# 1019          NaN          NaN
# 1020          NaN          NaN
# 1021          NaN          NaN
# 1022          NaN          NaN
# 1023          NaN          NaN
#
#                                       Institution Name         Country  \
# 0          Massachusetts Institute of Technology (MIT)   United States
# 1                                  Stanford University   United States
# 2                                   Harvard University   United States
# 3                                 University of Oxford  United Kingdom
# 4         California Institute of Technology (Caltech)   United States
# ...                                                ...             ...
# 1019              Université Sorbonne Nouvelle Paris 3          France
# ...

# %%
isinstance(df3.iloc[22,0], int)
# Out:
# False

# %%
df3.dtypes
# Out:
# Rank in 2020                    object
# Rank in 2019                    object
# Institution Name                object
# Country                         object
# Classification_size             object
# Focus                           object
# Research Intensity              object
# Age                             object
# Status                          object
# Academic_Reputation_RANK        object
# Academic_Reputation_SCORE       object
# Employer_Reputation_RANK        object
# Employer_Reputation_SCORE       object
# Faculty_Student_RANK            object
# Faculty_Student_SCORE           object
# Citations_per_Faculty_RANK      object
# Citations_per_Faculty_SCORE     object
# International_Faculty_RANK      object
# International_Faculty_SCORE     object
# International_Students_RANK     object
# International_Students_SCORE    object
# Overall Score                   object
# dtype: object

# %%
df3_ranking_only_2020= df3[df3['Rank in 2020'].isnull()]
df3_ranking_only_2020
# Out:
#      Rank in 2020 Rank in 2019  \
# 1002          NaN          NaN
# 1003          NaN          NaN
# 1004          NaN          NaN
# 1005          NaN          NaN
# 1006          NaN          NaN
# 1007          NaN          NaN
# 1008          NaN          NaN
# 1009          NaN          NaN
# 1010          NaN          NaN
# 1011          NaN          NaN
# 1012          NaN          NaN
# 1013          NaN          NaN
# 1014          NaN          NaN
# 1015          NaN          NaN
# 1016          NaN          NaN
# 1017          NaN          NaN
# 1018          NaN          NaN
# 1019          NaN          NaN
# 1020          NaN          NaN
# 1021          NaN          NaN
# 1022          NaN          NaN
# 1023          NaN          NaN
#
#                                        Institution Name         Country  \
# 1002                         Baylor College of Medicine   United States
# 1003                       BI Norwegian Business School          Norway
# ...

# %% [markdown]
# visualizing missing data

# %%
import missingno as msno

# %matplotlib inline

# %%
msno.matrix(df3.sample(250))
# Out:
# <AxesSubplot:>

# %%
msno.bar(df3.sample(500))
# Out:
# <AxesSubplot:>

# %% [markdown]
# to get the correlation between missing valuesusing heat map
# The missingno correlation heatmap measures nullity correlation: how strongly the presence or absence of one variable affects the presence of another

# %%
msno.heatmap(df3)
# Out:
# <AxesSubplot:>

# %%
df3 = df3.iloc[:, [i for i, n in enumerate(np.var(df3.isnull(), axis='rows')) if n > 0]]
corr_mat = df3.isnull().corr()
print(corr_mat)
# Out:
#                               Rank in 2020  Rank in 2019     Focus  \
# Rank in 2020                      1.000000      0.538803 -0.022461
# Rank in 2019                      0.538803      1.000000  0.190308
# Focus                            -0.022461      0.190308  1.000000
# Research Intensity               -0.022955      0.184619  0.978456
# Age                               0.022993      0.087199  0.510750
# Status                            0.037277      0.347566  0.600034
# Academic_Reputation_RANK          0.023440      0.198188  0.124066
# Academic_Reputation_SCORE         0.023440      0.198188  0.124066
# Employer_Reputation_RANK         -0.018837      0.138886  0.098618
# Employer_Reputation_SCORE        -0.018837      0.138886  0.098618
# Faculty_Student_RANK              0.080227      0.138268  0.103033
# Faculty_Student_SCORE             0.080227      0.138268  0.103033
# Citations_per_Faculty_RANK       -0.044256      0.146144  0.036841
# ...

# %%
#drop features not used for ranking  :'Classification_size', 'Focus','Research Intensity' 'Age', 'Size']
to_drop =['Focus','Research Intensity', 'Age', 'Status']

# %%
df3_rankingfactors = df3.drop(to_drop, axis=1)

# %%
print (df3_rankingfactors)
# Out:
#      Rank in 2020 Rank in 2019 Academic_Reputation_RANK  \
# 0               1            1                      100
# 1               2            2                      100
# 2               3            3                      100
# 3               4            5                      100
# 4               5            4                     97.8
# ...           ...          ...                      ...
# 1019          NaN          NaN                     37.7
# 1020          NaN          NaN                     45.6
# 1021          NaN          NaN                      NaN
# 1022          NaN          NaN                     20.8
# 1023          NaN          NaN                      NaN
#
#      Academic_Reputation_SCORE Employer_Reputation_RANK  \
# 0                            5                      100
# 1                            4                      100
# 2                            1                      100
# 3                            3                      100
# ...
