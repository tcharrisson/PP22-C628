# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
university_ranking18 = pd.read_csv('2018-QS-World-University-Rankings.csv',
                                   encoding='latin-1',header=[0,1])
university_ranking19 = pd.read_csv('2019-QS-World-University-Rankings.csv',
                                   encoding='latin-1',header=[0,1])
university_ranking20 = pd.read_csv('2020-QS-World-University-Rankings.csv',
                                   encoding='latin-1',header=[0,1])

# %% [markdown]
# # **For 2020 Data**

# %%
university_ranking20.head()
# Out:
#         Rank in 2020       Rank in 2019  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1
# 0                  1                  1
# 1                  2                  2
# 2                  3                  3
# 3                  4                  5
# 4                  5                  4
#
#                                Institution Name            Country  \
#                              Unnamed: 2_level_1 Unnamed: 3_level_1
# 0   Massachusetts Institute of Technology (MIT)      United States
# 1                           Stanford University      United States
# 2                            Harvard University      United States
# 3                          University of Oxford     United Kingdom
# 4  California Institute of Technology (Caltech)      United States
#
#   Classification Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#             SIZE              FOCUS RESEARCH INTENSITY                AGE
# 0              M                 CO                 VH                5.0
# 1              L                 FC                 VH                5.0
# 2              L                 FC                 VH                5.0
# 3              L                 FC                 VH                5.0
# 4              S                 CO                 VH                5.0
#
#   Unnamed: 8_level_0 Academic Reputation  ... Unnamed: 12_level_0  \
#               STATUS               SCORE  ...                RANK
# 0                  B                 100  ...                   4
# 1                  B                 100  ...                   5
# 2                  B                 100  ...                   1
# 3                  A                 100  ...                   3
# 4                  B                97.8  ...                  74
#
#   Faculty Student Unnamed: 14_level_0 Citations per Faculty  \
#             SCORE                RANK                 SCORE
# 0             100                  15                  99.8
# 1             100                  12                  98.6
# 2            98.7                  40                  99.6
# 3             100                   8                  84.7
# 4             100                   4                   100
#
#   Unnamed: 16_level_0 International Faculty Unnamed: 18_level_0  \
#                  RANK                 SCORE                RANK
# 0                   7                   100                  43
# 1                  13                  99.8                  62
# 2                   8                  86.3                 186
# 3                  45                  99.7                  64
# 4                   4                  99.4                  72
#
#   International Students Unnamed: 20_level_0       Overall Score
#                    SCORE                RANK Unnamed: 21_level_1
# 0                   94.1                  87                 100
# 1                   67.7                 196                98.4
# 2                   62.2                 221                97.4
# 3                   98.5                  50                97.2
# 4                   87.3                 121                96.9
#
# [5 rows x 22 columns]

# %% [markdown]
# # **Aligning Columns**

# %%
cols = []
for column in university_ranking20:
    if column[0].startswith('Unnamed'):
        cols.append(column[1])
    elif column[1].startswith('Unnamed'):
        cols.append(column[0])
    else:
        cols.append(column[0]+'_'+column[1])
university_ranking20.columns = cols

# %%
cols
# Out:
# ['Rank in 2020',
#  'Rank in 2019',
#  'Institution Name',
#  'Country',
#  'Classification_SIZE',
#  'FOCUS',
#  'RESEARCH INTENSITY',
#  'AGE',
#  'STATUS',
#  'Academic Reputation_SCORE',
#  'RANK',
#  'Employer Reputation_SCORE',
#  'RANK',
#  'Faculty Student_SCORE',
#  'RANK',
#  'Citations per Faculty_SCORE',
#  'RANK',
#  'International Faculty_SCORE',
#  'RANK',
#  'International Students_SCORE',
#  'RANK',
#  'Overall Score']

# %% [markdown]
# # **Cleaning Data**

# %%
university_ranking20.replace('-', np.nan,inplace=True)

# %%
university_ranking20_only_ranking = university_ranking20[~university_ranking20['Rank in 2020'].isnull()]

# %%
university_ranking20_only_ranking.head()
# Out:
#   Rank in 2020 Rank in 2019                              Institution Name  \
# 0            1            1   Massachusetts Institute of Technology (MIT)
# 1            2            2                           Stanford University
# 2            3            3                            Harvard University
# 3            4            5                          University of Oxford
# 4            5            4  California Institute of Technology (Caltech)
#
#           Country Classification_SIZE FOCUS RESEARCH INTENSITY  AGE STATUS  \
# 0   United States                   M    CO                 VH  5.0      B
# 1   United States                   L    FC                 VH  5.0      B
# 2   United States                   L    FC                 VH  5.0      B
# 3  United Kingdom                   L    FC                 VH  5.0      A
# 4   United States                   S    CO                 VH  5.0      B
#
#   Academic Reputation_SCORE  ... RANK Faculty Student_SCORE RANK  \
# 0                       100  ...    4                   100   15
# 1                       100  ...    5                   100   12
# 2                       100  ...    1                  98.7   40
# 3                       100  ...    3                   100    8
# 4                      97.8  ...   74                   100    4
#
#   Citations per Faculty_SCORE RANK International Faculty_SCORE RANK  \
# 0                        99.8    7                         100   43
# 1                        98.6   13                        99.8   62
# 2                        99.6    8                        86.3  186
# 3                        84.7   45                        99.7   64
# 4                         100    4                        99.4   72
#
#   International Students_SCORE RANK Overall Score
# 0                         94.1   87           100
# 1                         67.7  196          98.4
# 2                         62.2  221          97.4
# 3                         98.5   50          97.2
# 4                         87.3  121          96.9
#
# [5 rows x 22 columns]

# %%
university_ranking20_only_ranking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 0 to 1001
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Rank in 2020                  1002 non-null   object
#  1   Rank in 2019                  952 non-null    object
#  2   Institution Name              1002 non-null   object
#  3   Country                       1002 non-null   object
#  4   Classification_SIZE           1002 non-null   object
#  5   FOCUS                         979 non-null    object
#  6   RESEARCH INTENSITY            978 non-null    object
#  7   AGE                           980 non-null    float64
#  8   STATUS                        962 non-null    object
#  9   Academic Reputation_SCORE     581 non-null    object
#  10  RANK                          581 non-null    object
#  11  Employer Reputation_SCORE     620 non-null    object
#  12  RANK                          620 non-null    object
#  13  Faculty Student_SCORE         709 non-null    object
#  14  RANK                          709 non-null    object
#  15  Citations per Faculty_SCORE   677 non-null    object
#  16  RANK                          677 non-null    object
#  17  International Faculty_SCORE   682 non-null    object
#  18  RANK                          682 non-null    object
#  19  International Students_SCORE  688 non-null    object
#  20  RANK                          688 non-null    object
#  21  Overall Score                 1002 non-null   object
# dtypes: float64(1), object(21)
# memory usage: 180.0+ KB

# %%
university_ranking20_only_ranking.loc['Rank in 2020'] = university_ranking20_only_ranking['Rank in 2020'].str.strip().str.replace('=','')
# Out:
# C:\Users\kenny\anaconda3\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
university_ranking20_only_ranking.drop(university_ranking20_only_ranking.index[len(university_ranking20_only_ranking)-1], inplace=True)
# Out:
# C:\Users\kenny\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
university_ranking20_only_ranking['Country'].unique()
# Out:
# array(['United States', 'United Kingdom', 'Switzerland', 'Singapore',
#        'China', 'Japan', 'Hong Kong', 'Australia', 'Canada',
#        'South Korea', 'Netherlands', 'France', 'Germany', 'Taiwan',
#        'Malaysia', 'Argentina', 'Belgium', 'Denmark', 'New Zealand',
#        'Russia', 'Sweden', 'Mexico', 'Finland', 'Ireland', 'Brazil',
#        'Norway', 'Chile', 'Italy', 'India', 'Austria', 'Israel', 'Spain',
#        'Saudi Arabia', 'South Africa', 'Kazakhstan', 'Colombia',
#        'Lebanon', 'Thailand', 'United Arab Emirates', 'Qatar',
#        'Czech Republic', 'Indonesia', 'Brunei', 'Estonia', 'Poland',
#        'Portugal', 'Belarus', 'Philippines', 'Pakistan', 'Oman', 'Macau',
#        'Egypt', 'Iran', 'Turkey', 'Greece', 'Lithuania', 'Peru',
#        'Uruguay', 'Ukraine', 'Cuba', 'Hungary', 'Costa Rica', 'Slovenia',
#        'Jordan', 'Latvia', 'Venezuela', 'Iraq', 'Vietnam', 'Slovakia',
#        'Bulgaria', 'Ecuador', 'Croatia', 'Romania', 'Azerbaijan',
#        'Bangladesh', 'Kuwait', 'Puerto Rico', 'Paraguay', 'Panama',
#        'Bahrain', 'Serbia', 'Sri Lanka'], dtype=object)

# %%
university_ranking20_only_ranking['Classification_SIZE'].unique()
# Out:
# array(['M', 'L', 'S', 'XL'], dtype=object)

# %%
university_ranking20_only_ranking['FOCUS'].isnull().sum()
# Out:
# 23

# %%
university_ranking20_only_ranking[university_ranking20_only_ranking['RESEARCH INTENSITY'].isnull()]
# Out:
#     Rank in 2020 Rank in 2019  \
# 52            53           50
# 254         253=          NaN
# 396         395=          NaN
# 491         491=      521-530
# 599      591-600          NaN
# 659      651-700      561-570
# 684      651-700      601-650
# 690      651-700         495=
# 697      651-700      651-700
# 718      701-750      751-800
# 733      701-750          NaN
# 850     801-1000      751-800
# 857     801-1000          NaN
# 870     801-1000          NaN
# 888     801-1000          NaN
# 894     801-1000     801-1000
# 895     801-1000      701-750
# 907     801-1000          NaN
# 910     801-1000     801-1000
# 912     801-1000     801-1000
# 932     801-1000     801-1000
# 945     801-1000     801-1000
# 946     801-1000          NaN
# 974     801-1000     801-1000
#
#                                       Institution Name         Country  \
# 52           Université PSL (Paris Sciences & Lettres)          France
# 254                                University of Paris          France
# 396                                 Tampere University         Finland
# 491              Lappeenranta University of Technology         Finland
# 599                          University of Côte d'Azur          France
# 659  Indiana University-Purdue University Indianapolis   United States
# 684                         Universidad del Pais Vasco           Spain
# 690                              Universität Hohenheim         Germany
# 697                                University of Minho        Portugal
# 718                       London South Bank University  United Kingdom
# 733                            Universidad de Alicante           Spain
# 850                              Kent State University   United States
# 857                   Liverpool John Moores University  United Kingdom
# 870                                Politecnico di Bari           Italy
# 888                        Sheffield Hallam University  United Kingdom
# 894                    Tecnológico de Costa Rica (TEC)      Costa Rica
# 895                              Texas Tech University   United States
# 907                                Universidad de Lima            Peru
# 910                           Universidad de Monterrey          Mexico
# 912                              Universidad de Oviedo           Spain
# 932                               Universidade de Vigo           Spain
# 945                 Università  degli Studi di Palermo           Italy
# 946                                 Universität Siegen         Germany
# 974                     University of Montana Missoula   United States
#
#     Classification_SIZE FOCUS RESEARCH INTENSITY  AGE STATUS  \
# 52                    L   NaN                NaN  1.0    NaN
# 254                  XL   NaN                NaN  1.0    NaN
# 396                   L   NaN                NaN  1.0    NaN
# 491                   S   NaN                NaN  NaN      A
# 599                  XL   NaN                NaN  1.0    NaN
# 659                   L   NaN                NaN  NaN    NaN
# 684                  XL   NaN                NaN  NaN    NaN
# 690                   M   NaN                NaN  NaN    NaN
# 697                   L   NaN                NaN  NaN    NaN
# 718                   M   NaN                NaN  3.0    NaN
# 733                   L   NaN                NaN  3.0    NaN
# 850                   L   NaN                NaN  5.0      A
# 857                   L   NaN                NaN  NaN    NaN
# 870                   M   NaN                NaN  NaN    NaN
# 888                   L   NaN                NaN  NaN    NaN
# 894                   M   NaN                NaN  5.0    NaN
# 895                  XL   NaN                NaN  NaN    NaN
# 907                   M   NaN                NaN  4.0    NaN
# 910                   M    SP                NaN  4.0      A
# 912                   L   NaN                NaN  NaN    NaN
# 932                   L   NaN                NaN  NaN    NaN
# 945                   L   NaN                NaN  5.0      A
# 946                   L   NaN                NaN  NaN    NaN
# 974                   M   NaN                NaN  5.0      A
#
#     Academic Reputation_SCORE  ...  RANK Faculty Student_SCORE RANK  \
# 52                       77.7  ...    20                   100   21
# 254                      48.5  ...  501+                  33.5  457
# 396                      24.8  ...   312                    29  517
# 491                       6.6  ...  501+                  23.6  599
# 599                       NaN  ...   NaN                   NaN  NaN
# 659                       NaN  ...   NaN                  53.9  275
# 684                       NaN  ...   NaN                  44.7  338
# 690                       NaN  ...   NaN                   NaN  NaN
# 697                       NaN  ...   NaN                  31.4  480
# 718                       NaN  ...   NaN                   NaN  NaN
# 733                       NaN  ...   NaN                  31.3  483
# 850                       NaN  ...   NaN                   NaN  NaN
# 857                       NaN  ...   NaN                   NaN  NaN
# 870                       NaN  ...   NaN                   NaN  NaN
# 888                       NaN  ...   401                   NaN  NaN
# 894                       NaN  ...   321                  26.4  563
# 895                       NaN  ...   NaN                   NaN  NaN
# 907                       NaN  ...   263                   NaN  NaN
# 910                       NaN  ...   NaN                   NaN  NaN
# 912                       NaN  ...   NaN                   NaN  NaN
# 932                       NaN  ...   NaN                   NaN  NaN
# 945                       NaN  ...   NaN                   NaN  NaN
# 946                       NaN  ...   NaN                   NaN  NaN
# 974                       NaN  ...   NaN                   NaN  NaN
#
#     Citations per Faculty_SCORE RANK International Faculty_SCORE RANK  \
# 52                         26.2  470                        67.1  262
# 254                        46.1  265                        19.1  558
# 396                        38.1  345                        29.2  469
# 491                        56.3  169                        49.4  339
# 599                        29.8  434                        66.2  264
# 659                         NaN  NaN                         NaN  NaN
# 684                         NaN  NaN                         NaN  NaN
# 690                        42.5  305                         NaN  NaN
# 697                         NaN  NaN                        21.9  522
# 718                         NaN  NaN                        60.2  293
# 733                         NaN  NaN                         NaN  NaN
# 850                        31.9  420                          20  550
# 857                         NaN  NaN                        44.7  363
# 870                        48.1  248                         NaN  NaN
# 888                         NaN  NaN                        30.7  453
# 894                         NaN  NaN                         NaN  NaN
# 895                        19.1  565                        39.2  403
# 907                         NaN  NaN                         NaN  NaN
# 910                         NaN  NaN                         NaN  NaN
# 912                        18.6  574                         NaN  NaN
# 932                        22.6  514                         NaN  NaN
# 945                        26.5  466                         NaN  NaN
# 946                         NaN  NaN                        37.1  415
# 974                        22.6  512                         NaN  NaN
#
#     International Students_SCORE  RANK Overall Score
# 52                          72.1   175          73.4
# 254                          7.5  601+          37.5
# 396                          8.6  601+          28.4
# 491                         28.6   444          24.3
# 599                         68.2   192   20.3 - 20.4
# 659                          NaN   NaN   16.7 - 18.4
# 684                          NaN   NaN   16.7 - 18.4
# 690                         34.4   395   16.7 - 18.4
# 697                          NaN   NaN   16.7 - 18.4
# 718                         92.7    98   15.2 - 16.6
# 733                         16.1   583   15.2 - 16.6
# 850                          NaN   NaN      9 - 14.1
# 857                         32.7   407      9 - 14.1
# 870                          NaN   NaN      9 - 14.1
# 888                         20.2   530      9 - 14.1
# 894                          NaN   NaN      9 - 14.1
# 895                          NaN   NaN      9 - 14.1
# 907                          NaN   NaN      9 - 14.1
# 910                          NaN   NaN      9 - 14.1
# 912                          NaN   NaN      9 - 14.1
# 932                          NaN   NaN      9 - 14.1
# 945                          NaN   NaN      9 - 14.1
# 946                         23.7   489      9 - 14.1
# 974                          NaN   NaN      9 - 14.1
#
# [24 rows x 22 columns]

# %%
university_ranking20_only_ranking.groupby('Country')['Institution Name'].count().nlargest(20)
# Out:
# Country
# United States     157
# United Kingdom     84
# Germany            46
# China              42
# Japan              41
# Australia          35
# Italy              34
# France             31
# South Korea        30
# Spain              27
# Canada             26
# Russia             25
# India              24
# Malaysia           20
# Brazil             19
# Poland             16
# Taiwan             16
# Argentina          13
# Mexico             13
# Netherlands        13
# Name: Institution Name, dtype: int64

# %% [markdown]
# # **For 2019 data**

# %%
university_ranking19.head()
# Out:
#                 2019               2018  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1
# 0                  1                  1
# 1                  2                  2
# 2                  3                  3
# 3                  4                  4
# 4                  5                  6
#
#                                Institution Name            Country  \
#                              Unnamed: 2_level_1 Unnamed: 3_level_1
# 0   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)      United States
# 1                           STANFORD UNIVERSITY      United States
# 2                            HARVARD UNIVERSITY      United States
# 3  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)      United States
# 4                          UNIVERSITY OF OXFORD     United Kingdom
#
#   Classification Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#             SIZE              FOCUS RESEARCH INTENSITY                AGE
# 0              M                 CO                 VH                5.0
# 1              L                 FC                 VH                5.0
# 2              L                 FC                 VH                5.0
# 3              S                 CO                 VH                5.0
# 4              L                 FC                 VH                5.0
#
#   Unnamed: 8_level_0 Academic Reputation  ... Unnamed: 12_level_0  \
#               STATUS               SCORE  ...                RANK
# 0                  B                 100  ...                   4
# 1                  B                 100  ...                   5
# 2                  B                 100  ...                   1
# 3                  B                98.7  ...                  72
# 4                  A                 100  ...                   3
#
#   Faculty Student Unnamed: 14_level_0 Citations per Faculty  \
#             SCORE                RANK                 SCORE
# 0             100                  17                  99.8
# 1             100                  16                    99
# 2            99.3                  40                  99.8
# 3             100                   4                   100
# 4             100                   7                    83
#
#   Unnamed: 16_level_0 International Faculty Unnamed: 18_level_0  \
#                  RANK                 SCORE                RANK
# 0                   8                   100                  41
# 1                  13                  99.8                  56
# 2                   9                  92.1                 151
# 3                   5                  96.8                 115
# 4                  56                  99.6                  63
#
#   International Students Unnamed: 20_level_0       Overall Score
#                    SCORE                RANK Unnamed: 21_level_1
# 0                   95.5                  77                 100
# 1                   70.5                 190                98.6
# 2                   75.7                 164                98.5
# 3                   90.3                 103                97.2
# 4                   98.8                  43                96.8
#
# [5 rows x 22 columns]

# %% [markdown]
# # **Aligning Columns**

# %%
cols = []
for column in university_ranking19:
    if column[0].startswith('Unnamed'):
        cols.append(column[1])
    elif column[1].startswith('Unnamed'):
        cols.append(column[0])
    else:
        cols.append(column[0]+'_'+column[1])
university_ranking19.columns = cols

# %%
cols
# Out:
# ['2019',
#  '2018',
#  'Institution Name',
#  'Country',
#  'Classification_SIZE',
#  'FOCUS',
#  'RESEARCH INTENSITY',
#  'AGE',
#  'STATUS',
#  'Academic Reputation_SCORE',
#  'RANK',
#  'Employer Reputation_SCORE',
#  'RANK',
#  'Faculty Student_SCORE',
#  'RANK',
#  'Citations per Faculty_SCORE',
#  'RANK',
#  'International Faculty_SCORE',
#  'RANK',
#  'International Students_SCORE',
#  'RANK',
#  'Overall Score']

# %% [markdown]
# # **Cleaning Data**

# %%
university_ranking19.replace('-', np.nan,inplace=True)

# %%
university_ranking19_only_ranking = university_ranking19[~university_ranking19['Rank in 2019'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 'Rank in 2019'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3140/24737804.py in <module>
# ----> 1 university_ranking19_only_ranking = university_ranking19[~university_ranking19['Rank in 2019'].isnull()]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Rank in 2019'

# %%
university_ranking19_only_ranking.head()

# %%
university_ranking19_only_ranking.info()

# %%
university_ranking19_only_ranking.loc['Rank in 2020'] = university_ranking19_only_ranking['Rank in 2020'].str.strip().str.replace('=','')

# %%
university_ranking19_only_ranking.drop(university_ranking19_only_ranking.index[len(university_ranking19_only_ranking)-1], inplace=True)

# %%
university_ranking19_only_ranking['Country'].unique()

# %%
university_ranking19_only_ranking['Classification_SIZE'].unique()

# %%
university_ranking19_only_ranking['FOCUS'].isnull().sum()

# %%
university_ranking19_only_ranking[university_ranking19_only_ranking['RESEARCH INTENSITY'].isnull()]

# %%
university_ranking19_only_ranking.groupby('Country')['Institution Name'].count().nlargest(20)

# %% [markdown]
# # **For 2018 data**

# %%
university_ranking18.head()

# %% [markdown]
# # **Aligning Columns**

# %%
cols = []
for column in university_ranking18:
    if column[0].startswith('Unnamed'):
        cols.append(column[1])
    elif column[1].startswith('Unnamed'):
        cols.append(column[0])
    else:
        cols.append(column[0]+'_'+column[1])
university_ranking18.columns = cols

# %%
cols

# %% [markdown]
# # **Cleaning Data**

# %%
university_ranking18.replace('-', np.nan,inplace=True)

# %%
university_ranking18_only_ranking = university_ranking18[~university_ranking19['Rank in 2019'].isnull()]

# %%
university_ranking18_only_ranking.head()

# %%
university_ranking18_only_ranking.info()

# %%
university_ranking18_only_ranking.loc['Rank in 2020'] = university_ranking18_only_ranking['Rank in 2020'].str.strip().str.replace('=','')

# %%
university_ranking18_only_ranking.drop(university_ranking18_only_ranking.index[len(university_ranking18_only_ranking)-1], inplace=True)

# %%
university_ranking18_only_ranking['Country'].unique()

# %%
university_ranking18_only_ranking['Classification_SIZE'].unique()

# %%
university_ranking18_only_ranking['FOCUS'].isnull().sum()

# %%
university_ranking18_only_ranking[university_ranking18_only_ranking['RESEARCH INTENSITY'].isnull()]

# %%
university_ranking18_only_ranking.groupby('Country')['Institution Name'].count().nlargest(20)
