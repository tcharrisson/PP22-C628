# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
university_ranking18 = pd.read_csv('2018-QS-World-University-Rankings.csv',
                                   encoding='latin-1', header = [0,1])
university_ranking19 = pd.read_csv('2019-QS-World-University-Rankings.csv',
                                   encoding='latin-1', header = [0,1])
university_ranking20 = pd.read_csv('2020-QS-World-University-Rankings.csv',
                                   encoding='latin-1', header = [0,1])

# %%
university_ranking18.head()
# Out:
#                 2018               2017  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1
# 0                  1                  1
# 1                  2                  2
# 2                  3                  3
# 3                  4                  5
# 4                  5                  4
#
#                                Institution Name            Country  \
#                              Unnamed: 2_level_1 Unnamed: 3_level_1
# 0  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)       United States
# 1                           STANFORD UNIVERSITY      United States
# 2                            HARVARD UNIVERSITY      United States
# 3  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)      United States
# 4                       UNIVERSITY OF CAMBRIDGE     United Kingdom
#
#   Classification Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#             SIZE              FOCUS RESEARCH INTENSITY                AGE
# 0              M                 CO                 VH                5.0
# 1              L                 FC                 VH                5.0
# 2              L                 FC                 VH                5.0
# 3              S                 CO                 VH                5.0
# 4              L                 FC                 VH                5.0
#
#   Unnamed: 8_level_0 Academic Reputation  ... Unnamed: 12_level_0  \
#               STATUS               SCORE  ...                RANK
# 0                  B                 100  ...                   4
# 1                  B                 100  ...                   5
# 2                  B                 100  ...                   3
# 3                  B                99.5  ...                  77
# 4                  A                 100  ...                   1
#
#   Faculty Student Unnamed: 14_level_0 Citations per Faculty  \
#             SCORE                RANK                 SCORE
# 0             100                  14                  99.9
# 1             100                  12                  99.4
# 2            98.3                  38                  99.9
# 3             100                   3                   100
# 4             100                  10                  78.3
#
#   Unnamed: 16_level_0 International Faculty Unnamed: 18_level_0  \
#                  RANK                 SCORE                RANK
# 0                   8                   100                  36
# 1                  12                  99.6                  54
# 2                   9                  96.5                 103
# 3                   4                  93.4                 126
# 4                  75                  97.4                  87
#
#   International Students Unnamed: 20_level_0       Overall Score
#                    SCORE                RANK Unnamed: 21_level_1
# 0                   96.1                  70                 100
# 1                   72.7                 177                98.7
# 2                   75.2                 165                98.4
# 3                   89.2                 106                97.7
# 4                   97.7                  57                95.6
#
# [5 rows x 22 columns]

# %%
university_ranking19.head()
# Out:
#                 2019               2018  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1
# 0                  1                  1
# 1                  2                  2
# 2                  3                  3
# 3                  4                  4
# 4                  5                  6
#
#                                Institution Name            Country  \
#                              Unnamed: 2_level_1 Unnamed: 3_level_1
# 0   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)      United States
# 1                           STANFORD UNIVERSITY      United States
# 2                            HARVARD UNIVERSITY      United States
# 3  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)      United States
# 4                          UNIVERSITY OF OXFORD     United Kingdom
#
#   Classification Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#             SIZE              FOCUS RESEARCH INTENSITY                AGE
# 0              M                 CO                 VH                5.0
# 1              L                 FC                 VH                5.0
# 2              L                 FC                 VH                5.0
# 3              S                 CO                 VH                5.0
# 4              L                 FC                 VH                5.0
#
#   Unnamed: 8_level_0 Academic Reputation  ... Unnamed: 12_level_0  \
#               STATUS               SCORE  ...                RANK
# 0                  B                 100  ...                   4
# 1                  B                 100  ...                   5
# 2                  B                 100  ...                   1
# 3                  B                98.7  ...                  72
# 4                  A                 100  ...                   3
#
#   Faculty Student Unnamed: 14_level_0 Citations per Faculty  \
#             SCORE                RANK                 SCORE
# 0             100                  17                  99.8
# 1             100                  16                    99
# 2            99.3                  40                  99.8
# 3             100                   4                   100
# 4             100                   7                    83
#
#   Unnamed: 16_level_0 International Faculty Unnamed: 18_level_0  \
#                  RANK                 SCORE                RANK
# 0                   8                   100                  41
# 1                  13                  99.8                  56
# 2                   9                  92.1                 151
# 3                   5                  96.8                 115
# 4                  56                  99.6                  63
#
#   International Students Unnamed: 20_level_0       Overall Score
#                    SCORE                RANK Unnamed: 21_level_1
# 0                   95.5                  77                 100
# 1                   70.5                 190                98.6
# 2                   75.7                 164                98.5
# 3                   90.3                 103                97.2
# 4                   98.8                  43                96.8
#
# [5 rows x 22 columns]

# %%
university_ranking18.columns
# Out:
# MultiIndex([(                  '2018',  'Unnamed: 0_level_1'),
#             (                  '2017',  'Unnamed: 1_level_1'),
#             (      'Institution Name',  'Unnamed: 2_level_1'),
#             (               'Country',  'Unnamed: 3_level_1'),
#             (        'Classification',                'SIZE'),
#             (    'Unnamed: 5_level_0',               'FOCUS'),
#             (    'Unnamed: 6_level_0',  'RESEARCH INTENSITY'),
#             (    'Unnamed: 7_level_0',                 'AGE'),
#             (    'Unnamed: 8_level_0',              'STATUS'),
#             (   'Academic Reputation',               'SCORE'),
#             (   'Unnamed: 10_level_0',                'RANK'),
#             (   'Employer Reputation',               'SCORE'),
#             (   'Unnamed: 12_level_0',                'RANK'),
#             (       'Faculty Student',               'SCORE'),
#             (   'Unnamed: 14_level_0',                'RANK'),
#             ( 'Citations per Faculty',               'SCORE'),
#             (   'Unnamed: 16_level_0',                'RANK'),
#             ( 'International Faculty',               'SCORE'),
#             (   'Unnamed: 18_level_0',                'RANK'),
#             ('International Students',               'SCORE'),
#             (   'Unnamed: 20_level_0',                'RANK'),
#             (         'Overall Score', 'Unnamed: 21_level_1')],
#            )

# %%
university_ranking18.head()
# Out:
#                 2018               2017  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1
# 0                  1                  1
# 1                  2                  2
# 2                  3                  3
# 3                  4                  5
# 4                  5                  4
#
#                                Institution Name            Country  \
#                              Unnamed: 2_level_1 Unnamed: 3_level_1
# 0  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)       United States
# 1                           STANFORD UNIVERSITY      United States
# 2                            HARVARD UNIVERSITY      United States
# 3  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)      United States
# 4                       UNIVERSITY OF CAMBRIDGE     United Kingdom
#
#   Classification Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#             SIZE              FOCUS RESEARCH INTENSITY                AGE
# 0              M                 CO                 VH                5.0
# 1              L                 FC                 VH                5.0
# 2              L                 FC                 VH                5.0
# 3              S                 CO                 VH                5.0
# 4              L                 FC                 VH                5.0
#
#   Unnamed: 8_level_0 Academic Reputation  ... Unnamed: 12_level_0  \
#               STATUS               SCORE  ...                RANK
# 0                  B                 100  ...                   4
# 1                  B                 100  ...                   5
# 2                  B                 100  ...                   3
# 3                  B                99.5  ...                  77
# 4                  A                 100  ...                   1
#
#   Faculty Student Unnamed: 14_level_0 Citations per Faculty  \
#             SCORE                RANK                 SCORE
# 0             100                  14                  99.9
# 1             100                  12                  99.4
# 2            98.3                  38                  99.9
# 3             100                   3                   100
# 4             100                  10                  78.3
#
#   Unnamed: 16_level_0 International Faculty Unnamed: 18_level_0  \
#                  RANK                 SCORE                RANK
# 0                   8                   100                  36
# 1                  12                  99.6                  54
# 2                   9                  96.5                 103
# 3                   4                  93.4                 126
# 4                  75                  97.4                  87
#
#   International Students Unnamed: 20_level_0       Overall Score
#                    SCORE                RANK Unnamed: 21_level_1
# 0                   96.1                  70                 100
# 1                   72.7                 177                98.7
# 2                   75.2                 165                98.4
# 3                   89.2                 106                97.7
# 4                   97.7                  57                95.6
#
# [5 rows x 22 columns]

# %%
# Resolving columns
def resolve_columns(df: pd.core.frame.DataFrame) -> list:
    cols = []
    rankNumber = 1
    for column in df:
        if column[0].startswith('Unnamed'):
            if column[1].startswith('RANK'):
                cols.append(column[1] + '_' + str(rankNumber))
                rankNumber +=1
            else:
                cols.append(column[1])
        elif column[1].startswith('Unnamed'):
            if column[0].startswith('RANK'):
                cols.append(column[0] + '_' + str(rankNumber))
                rankNumber +=1
            else:
                cols.append(column[0])
        else:
            cols.append(column[0] + ' ' + column[1].capitalize())
    return cols

# %%
university_ranking18.columns = resolve_columns(university_ranking18)
university_ranking19.columns = resolve_columns(university_ranking19)
university_ranking20.columns = resolve_columns(university_ranking20)
university_ranking18.columns
# Out:
# Index(['2018', '2017', 'Institution Name', 'Country', 'Classification Size',
#        'FOCUS', 'RESEARCH INTENSITY', 'AGE', 'STATUS',
#        'Academic Reputation Score', 'RANK_1', 'Employer Reputation Score',
#        'RANK_2', 'Faculty Student Score', 'RANK_3',
#        'Citations per Faculty Score', 'RANK_4', 'International Faculty Score',
#        'RANK_5', 'International Students Score', 'RANK_6', 'Overall Score'],
#       dtype='object')

# %%
university_ranking18.head()
# Out:
#   2018 2017                              Institution Name         Country  \
# 0    1    1  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)    United States
# 1    2    2                           STANFORD UNIVERSITY   United States
# 2    3    3                            HARVARD UNIVERSITY   United States
# 3    4    5  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)   United States
# 4    5    4                       UNIVERSITY OF CAMBRIDGE  United Kingdom
#
#   Classification Size FOCUS RESEARCH INTENSITY  AGE STATUS  \
# 0                   M    CO                 VH  5.0      B
# 1                   L    FC                 VH  5.0      B
# 2                   L    FC                 VH  5.0      B
# 3                   S    CO                 VH  5.0      B
# 4                   L    FC                 VH  5.0      A
#
#   Academic Reputation Score  ... RANK_2 Faculty Student Score RANK_3  \
# 0                       100  ...      4                   100     14
# 1                       100  ...      5                   100     12
# 2                       100  ...      3                  98.3     38
# 3                      99.5  ...     77                   100      3
# 4                       100  ...      1                   100     10
#
#   Citations per Faculty Score RANK_4 International Faculty Score RANK_5  \
# 0                        99.9      8                         100     36
# 1                        99.4     12                        99.6     54
# 2                        99.9      9                        96.5    103
# 3                         100      4                        93.4    126
# 4                        78.3     75                        97.4     87
#
#   International Students Score RANK_6 Overall Score
# 0                         96.1     70           100
# 1                         72.7    177          98.7
# 2                         75.2    165          98.4
# 3                         89.2    106          97.7
# 4                         97.7     57          95.6
#
# [5 rows x 22 columns]

# %%
university_ranking19.head()
# Out:
#   2019 2018                              Institution Name         Country  \
# 0    1    1   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# 1    2    2                           STANFORD UNIVERSITY   United States
# 2    3    3                            HARVARD UNIVERSITY   United States
# 3    4    4  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)   United States
# 4    5    6                          UNIVERSITY OF OXFORD  United Kingdom
#
#   Classification Size FOCUS RESEARCH INTENSITY  AGE STATUS  \
# 0                   M    CO                 VH  5.0      B
# 1                   L    FC                 VH  5.0      B
# 2                   L    FC                 VH  5.0      B
# 3                   S    CO                 VH  5.0      B
# 4                   L    FC                 VH  5.0      A
#
#   Academic Reputation Score  ... RANK_2 Faculty Student Score RANK_3  \
# 0                       100  ...      4                   100     17
# 1                       100  ...      5                   100     16
# 2                       100  ...      1                  99.3     40
# 3                      98.7  ...     72                   100      4
# 4                       100  ...      3                   100      7
#
#   Citations per Faculty Score RANK_4 International Faculty Score RANK_5  \
# 0                        99.8      8                         100     41
# 1                          99     13                        99.8     56
# 2                        99.8      9                        92.1    151
# 3                         100      5                        96.8    115
# 4                          83     56                        99.6     63
#
#   International Students Score RANK_6 Overall Score
# 0                         95.5     77           100
# 1                         70.5    190          98.6
# 2                         75.7    164          98.5
# 3                         90.3    103          97.2
# 4                         98.8     43          96.8
#
# [5 rows x 22 columns]

# %%
university_ranking20.head()
# Out:
#   Rank in 2020 Rank in 2019                              Institution Name  \
# 0            1            1   Massachusetts Institute of Technology (MIT)
# 1            2            2                           Stanford University
# 2            3            3                            Harvard University
# 3            4            5                          University of Oxford
# 4            5            4  California Institute of Technology (Caltech)
#
#           Country Classification Size FOCUS RESEARCH INTENSITY  AGE STATUS  \
# 0   United States                   M    CO                 VH  5.0      B
# 1   United States                   L    FC                 VH  5.0      B
# 2   United States                   L    FC                 VH  5.0      B
# 3  United Kingdom                   L    FC                 VH  5.0      A
# 4   United States                   S    CO                 VH  5.0      B
#
#   Academic Reputation Score  ... RANK_2 Faculty Student Score RANK_3  \
# 0                       100  ...      4                   100     15
# 1                       100  ...      5                   100     12
# 2                       100  ...      1                  98.7     40
# 3                       100  ...      3                   100      8
# 4                      97.8  ...     74                   100      4
#
#   Citations per Faculty Score RANK_4 International Faculty Score RANK_5  \
# 0                        99.8      7                         100     43
# 1                        98.6     13                        99.8     62
# 2                        99.6      8                        86.3    186
# 3                        84.7     45                        99.7     64
# 4                         100      4                        99.4     72
#
#   International Students Score RANK_6 Overall Score
# 0                         94.1     87           100
# 1                         67.7    196          98.4
# 2                         62.2    221          97.4
# 3                         98.5     50          97.2
# 4                         87.3    121          96.9
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Checking for Null Values in the data

# %% [markdown]
# # det_columns =  Academic Reputation, Employer Reputation, Faculty to Student Ratio, Number of citations per faculty, International Faculty, International Students

# %%
#columns used for the determination of the rankings will be saved in a variable called det_columns
det_columns = ['Academic Reputation Score', 'Employer Reputation Score', 'Faculty Student Score',
               'Citations per Faculty Score', 'International Faculty Score', 'International Students Score']

# %%
university_ranking18.replace('-', np.nan,inplace=True)

# %%
# checking null values in 2018 dataset
# yellow color means null value
plt.figure(figsize=(12,6))
sns.heatmap(university_ranking18[det_columns].isnull(), cmap='viridis', cbar=False, yticklabels=False)

# %%
university_ranking19.replace('-', np.nan,inplace=True)

# %%
# checking null values in 2019 dataset
plt.figure(figsize=(12,6))
sns.heatmap(university_ranking19[det_columns].isnull(), cmap='viridis', cbar=False, yticklabels=False)

# %%
university_ranking20.replace('-', np.nan,inplace=True)

# %%
# Checking for null values in 2020 data
plt.figure(figsize=(12,6))
sns.heatmap(university_ranking20[det_columns].isnull(), cmap='viridis', cbar=False, yticklabels=False)

# %% [markdown]
# ### Univariate Analysis
# #### Bar Plot

# %%
university_ranking18.Country
# Out:
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4      United Kingdom
#             ...
# 979           Germany
# 980               NaN
# 981               NaN
# 982               NaN
# 983               NaN
# Name: Country, Length: 984, dtype: object

# %%
university_ranking18.Country.nunique()
# Out:
# 84

# %%
top_contries=university_ranking18.Country.value_counts().head()
top_contries
# Out:
# United States     159
# United Kingdom     78
# Germany            47
# France             44
# Japan              43
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
plt.title("Country")
sns.barplot(top_contries.index,top_contries);

# %%
plt.figure(figsize=(12,6))
plt.title("Age")
plt.xlabel("Age")
plt.ylabel("Number of Respondents")
plt.hist(university_ranking18.AGE,bins=10,color='purple')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\USER\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([  1.,   0.,  31.,   0.,   0., 127.,   0., 304.,   0., 496.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
university_ranking19.Country
# Out:
# 0        United States
# 1        United States
# 2        United States
# 3        United States
# 4       United Kingdom
#              ...
# 1020           Germany
# 1021               NaN
# 1022               NaN
# 1023               NaN
# 1024               NaN
# Name: Country, Length: 1025, dtype: object

# %%
university_ranking19.Country.nunique()
# Out:
# 85

# %%
top_contries19=university_ranking18.Country.value_counts().head()
top_contries19
# Out:
# United States     159
# United Kingdom     78
# Germany            47
# France             44
# Japan              43
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
plt.title("Country")
sns.barplot(top_contries19.index,top_contries);

# %%
plt.figure(figsize=(12,6))
plt.title("Age")
plt.xlabel("Age")
plt.ylabel("Number of Respondents")
plt.hist(university_ranking19.AGE,bins=10,color='purple')
# Out:
# (array([  8.,   0.,  38.,   0.,   0., 158.,   0., 324.,   0., 493.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
target_col = ['Overall Score']

# %% [markdown]
# ## Model Training

# %%
def clean_df(dataframe):
    '''
    \n Function for cleaning datasets.
    \n Accepts a DataFrame.
    \n Returns two DataFrames: Feature DataFrame and Target DataFrame.
    
    '''
    dataframe = pd.DataFrame(dataframe)
    missing= dataframe.isnull().sum().sum()
    print('Initial missing values : {}'.format(missing))
    row_num = dataframe.shape[0]
    dict = []
    for row in range(row_num):
        num=dataframe.iloc[row].isnull().sum()
        if num != 0:
            dict.append(row)
    dataframe = dataframe.drop(dict)
    feature_df = dataframe[det_columns]
    target_df = dataframe[target_col]
    missing= dataframe.isnull().sum().sum()
    print('Current missing values : {}'.format(missing))
    return feature_df, target_df

# %%
feature_18, target_c18 = clean_df(university_ranking18)
feature_19, target_c19 = clean_df(university_ranking19)
feature_20, target_c20 = clean_df(university_ranking20)
# Out:
# Initial missing values : 6880
# Current missing values : 0
# Initial missing values : 4382
# Current missing values : 0
# Initial missing values : 4424
# Current missing values : 0

# %%
plt.figure(figsize=(12,6))
sns.heatmap(feature_18.isnull(), cmap='viridis', cbar=False, yticklabels=False)
# cleaned the data successfully

# %%
# Concatenate The DataFrames
overall_feat = pd.concat([feature_18, feature_19, feature_20])
overall_targ = pd.concat([target_c18, target_c19, target_c20])

# %%
print(overall_feat.shape)
overall_feat.head()
# Out:
# (1368, 6)
#   Academic Reputation Score Employer Reputation Score Faculty Student Score  \
# 0                       100                       100                   100
# 1                       100                       100                   100
# 2                       100                       100                  98.3
# 3                      99.5                      85.4                   100
# 4                       100                       100                   100
#
#   Citations per Faculty Score International Faculty Score  \
# 0                        99.9                         100
# 1                        99.4                        99.6
# 2                        99.9                        96.5
# 3                         100                        93.4
# 4                        78.3                        97.4
#
#   International Students Score
# 0                         96.1
# 1                         72.7
# 2                         75.2
# 3                         89.2
# 4                         97.7

# %%
print(overall_targ.shape)
overall_targ.head()
# Out:
# (1368, 1)
#   Overall Score
# 0           100
# 1          98.7
# 2          98.4
# 3          97.7
# 4          95.6

# %% [markdown]
# #### No need to apply scalling because they all have the same range (100 - 0)

# %%
# Import libraries for training
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(overall_feat, 
                                                    overall_targ, 
                                                    test_size = 0.20, 
                                                    random_state = 42)

# %%
LR = LinearRegression()
# fitting the training data

LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
mae = mean_absolute_error(y_true= y_test, y_pred=y_pred)
mse = mean_squared_error(y_true=y_test, y_pred=y_pred, squared=True)
rmse = mean_squared_error(y_true=y_test, y_pred=y_pred, squared=False)
print('Mean Absolute Error : {:.3f}'.format(mae))
print('Mean Squred Error : {:.3f}'.format(mse))
print('Root Mean Squred Error : {:.3f}'.format(rmse))
# Out:
# Mean Absolute Error : 0.030
# Mean Squred Error : 0.001
# Root Mean Squred Error : 0.037

# %%
# Function to create a single row dataframe
def todataframe(Academic_Reputation_Score, Employer_Reputation_Score, Faculty_Student_Score,
    Citations_per_Faculty_Score, International_Faculty_Score, International_Students_Score):
    data = [{'Academic Reputation Score': Academic_Reputation_Score, 'Employer Reputation Score': Employer_Reputation_Score, 'Faculty Student Score' : Faculty_Student_Score,
    'Citations per Faculty Score' : Citations_per_Faculty_Score, 'International Faculty Score' :International_Faculty_Score, 'International Students Score': International_Students_Score}]

    df = pd.DataFrame(data =data)
    return df

# %%
df = todataframe(99.5,	85.4,	100,	100,	93.4,	89.2)
df.head()
# Out:
#    Academic Reputation Score  Employer Reputation Score  \
# 0                       99.5                       85.4
#
#    Faculty Student Score  Citations per Faculty Score  \
# 0                    100                          100
#
#    International Faculty Score  International Students Score
# 0                         93.4                          89.2

# %%
v = LR.predict(df)
print(v)
# Out:
# [[97.72839125]]

# %%
def pred(dataframe):
    pred= LR.predict(dataframe)
    return pred

# %% [markdown]
# #### Compare prediction to test targets

# %%
test = X_test.iloc[0: 5]

test_pred = pred(test)
test.head()
print(test_pred)
# Out:
# [[81.21267657]
#  [43.02839153]
#  [35.79060185]
#  [45.86358456]
#  [60.71139412]]

# %%
y_test.iloc[0: 5].head(5)
# Out:
#     Overall Score
# 34           81.2
# 207          43.1
# 277          35.8
# 181          45.9
# 115          60.7
