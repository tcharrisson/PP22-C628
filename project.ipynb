# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Get the data

# %%
df2018 = pd.read_csv('2018-QS-World-University-Rankings.csv', encoding='ISO-8859-1', header = [0,1])
df2019 = pd.read_csv('2019-QS-World-University-Rankings.csv', encoding='ISO-8859-1', header = [0,1])
df2020 = pd.read_csv('2020-QS-World-University-Rankings.csv', encoding='ISO-8859-1', header = [0,1])

# %%
df2018.head()
# Out:
#                 2018               2017  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1
# 0                  1                  1
# 1                  2                  2
# 2                  3                  3
# 3                  4                  5
# 4                  5                  4
#
#                                Institution Name            Country  \
#                              Unnamed: 2_level_1 Unnamed: 3_level_1
# 0  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)       United States
# 1                           STANFORD UNIVERSITY      United States
# 2                            HARVARD UNIVERSITY      United States
# 3  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)      United States
# 4                       UNIVERSITY OF CAMBRIDGE     United Kingdom
#
#   Classification Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#             SIZE              FOCUS RESEARCH INTENSITY                AGE
# ...

# %%
df2019.head()
# Out:
#                 2019               2018  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1
# 0                  1                  1
# 1                  2                  2
# 2                  3                  3
# 3                  4                  4
# 4                  5                  6
#
#                                Institution Name            Country  \
#                              Unnamed: 2_level_1 Unnamed: 3_level_1
# 0   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)      United States
# 1                           STANFORD UNIVERSITY      United States
# 2                            HARVARD UNIVERSITY      United States
# 3  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)      United States
# 4                          UNIVERSITY OF OXFORD     United Kingdom
#
#   Classification Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#             SIZE              FOCUS RESEARCH INTENSITY                AGE
# ...

# %%
df2020.head()
# Out:
#         Rank in 2020       Rank in 2019  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1
# 0                  1                  1
# 1                  2                  2
# 2                  3                  3
# 3                  4                  5
# 4                  5                  4
#
#                                Institution Name            Country  \
#                              Unnamed: 2_level_1 Unnamed: 3_level_1
# 0   Massachusetts Institute of Technology (MIT)      United States
# 1                           Stanford University      United States
# 2                            Harvard University      United States
# 3                          University of Oxford     United Kingdom
# 4  California Institute of Technology (Caltech)      United States
#
#   Classification Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#             SIZE              FOCUS RESEARCH INTENSITY                AGE
# ...

# %%
df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 22 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   (Rank in 2020, Unnamed: 0_level_1)        1002 non-null   object
#  1   (Rank in 2019, Unnamed: 1_level_1)        952 non-null    object
#  2   (Institution Name, Unnamed: 2_level_1)    1024 non-null   object
#  3   (Country, Unnamed: 3_level_1)             1024 non-null   object
#  4   (Classification, SIZE)                    1024 non-null   object
#  5   (Unnamed: 5_level_0, FOCUS)               1001 non-null   object
#  6   (Unnamed: 6_level_0, RESEARCH INTENSITY)  1000 non-null   object
#  7   (Unnamed: 7_level_0, AGE)                 1001 non-null   float64
#  8   (Unnamed: 8_level_0, STATUS)              982 non-null    object
#  9   (Academic Reputation, SCORE)              1024 non-null   object
# ...

# %% [markdown]
# # Resolving Columns

# %%
def resolve_columns(df: pd.core.frame.DataFrame) -> list:
    cols = []
    rankNumber = 1
    for column in df:
        if column[0].startswith('Unnamed'):
            if column[1].startswith('RANK'):
                cols.append(column[1] + '_' + str(rankNumber))
                rankNumber +=1
            else:
                cols.append(column[1])
        elif column[1].startswith('Unnamed'):
            if column[0].startswith('RANK'):
                cols.append(column[0] + '_' + str(rankNumber))
                rankNumber +=1
            else:
                cols.append(column[0])
        else:
            cols.append(column[0] + '_' + column[1])
    return cols

# %%
df2018.columns = resolve_columns(df2018)
df2019.columns = resolve_columns(df2019)
df2020.columns = resolve_columns(df2020)

# %%
df2018.head()
# Out:
#   2018 2017                              Institution Name         Country  \
# 0    1    1  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)    United States
# 1    2    2                           STANFORD UNIVERSITY   United States
# 2    3    3                            HARVARD UNIVERSITY   United States
# 3    4    5  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)   United States
# 4    5    4                       UNIVERSITY OF CAMBRIDGE  United Kingdom
#
#   Classification_SIZE FOCUS RESEARCH INTENSITY  AGE STATUS  \
# 0                   M    CO                 VH  5.0      B
# 1                   L    FC                 VH  5.0      B
# 2                   L    FC                 VH  5.0      B
# 3                   S    CO                 VH  5.0      B
# 4                   L    FC                 VH  5.0      A
#
#   Academic Reputation_SCORE  ... RANK_2 Faculty Student_SCORE RANK_3  \
# 0                       100  ...      4                   100     14
# ...

# %%
df2019.head()
# Out:
#   2019 2018                              Institution Name         Country  \
# 0    1    1   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)   United States
# 1    2    2                           STANFORD UNIVERSITY   United States
# 2    3    3                            HARVARD UNIVERSITY   United States
# 3    4    4  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)   United States
# 4    5    6                          UNIVERSITY OF OXFORD  United Kingdom
#
#   Classification_SIZE FOCUS RESEARCH INTENSITY  AGE STATUS  \
# 0                   M    CO                 VH  5.0      B
# 1                   L    FC                 VH  5.0      B
# 2                   L    FC                 VH  5.0      B
# 3                   S    CO                 VH  5.0      B
# 4                   L    FC                 VH  5.0      A
#
#   Academic Reputation_SCORE  ... RANK_2 Faculty Student_SCORE RANK_3  \
# 0                       100  ...      4                   100     17
# ...

# %%
df2020.head()
# Out:
#   Rank in 2020 Rank in 2019                              Institution Name  \
# 0            1            1   Massachusetts Institute of Technology (MIT)
# 1            2            2                           Stanford University
# 2            3            3                            Harvard University
# 3            4            5                          University of Oxford
# 4            5            4  California Institute of Technology (Caltech)
#
#           Country Classification_SIZE FOCUS RESEARCH INTENSITY  AGE STATUS  \
# 0   United States                   M    CO                 VH  5.0      B
# 1   United States                   L    FC                 VH  5.0      B
# 2   United States                   L    FC                 VH  5.0      B
# 3  United Kingdom                   L    FC                 VH  5.0      A
# 4   United States                   S    CO                 VH  5.0      B
#
# ...

# %% [markdown]
# # Checking for null values

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df2018.isnull(), cmap='viridis', cbar=False, yticklabels=False)
# yellow color means null value
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df2019.isnull(), cmap='viridis', cbar=False, yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df2020.isnull(), cmap='viridis', cbar=False, yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
df2018.replace('-', np.nan, inplace=True)
df2019.replace('-', np.nan, inplace=True)
df2020.replace('-', np.nan, inplace=True)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df2018.isnull(), cmap='viridis', cbar=False, yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df2019.isnull(), cmap='viridis', cbar=False, yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df2020.isnull(), cmap='viridis', cbar=False, yticklabels=False)
# Out:
# <AxesSubplot:>
